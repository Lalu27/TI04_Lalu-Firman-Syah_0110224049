# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/MyDrive/Praktikum/Praktikum02"

# %%
import pandas as pd

df = pd.read_csv(path + '/data/day.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
import sklearn.model_selection as sm
train_val_df, test_df = sm.train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = sm.train_test_split(train_val_df, test_size=0.1, random_state=42)

# %%
print("1. Data Training (80% dari total)\n")
train_df
# Out:
# 1. Data Training (80% dari total)
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 657      658  2012-10-19       4   1    10        0        5           1
# 163      164  2011-06-13       2   0     6        0        1           1
# 305      306  2011-11-02       4   0    11        0        3           1
# 111      112  2011-04-22       2   0     4        0        5           1
# 538      539  2012-06-22       3   1     6        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 264      265  2011-09-22       3   0     9        0        4           1
# 73        74  2011-03-15       1   0     3        0        2           1
# 479      480  2012-04-24       2   1     4        0        2           1
# 719      720  2012-12-20       4   1    12        0        4           1
# 140      141  2011-05-21       2   0     5        0        6           0
#
# ...

# %%
print("2. Data Validation (10% dari total)\n")
val_df
# Out:
# 2. Data Validation (10% dari total)
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 325      326  2011-11-22       4   0    11        0        2           1
# 410      411  2012-02-15       1   1     2        0        3           1
# 92        93  2011-04-03       2   0     4        0        0           0
# 47        48  2011-02-17       1   0     2        0        4           1
# 508      509  2012-05-23       2   1     5        0        3           1
# 442      443  2012-03-18       1   1     3        0        0           0
# 412      413  2012-02-17       1   1     2        0        5           1
# 417      418  2012-02-22       1   1     2        0        3           1
# 221      222  2011-08-10       3   0     8        0        3           1
# 591      592  2012-08-14       3   1     8        0        2           1
# 243      244  2011-09-01       3   0     9        0        4           1
# ...

# %%
print("3. Data Testing (20% dari total)\n")
test_df
# Out:
# 3. Data Testing (20% dari total)
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 703      704  2012-12-04       4   1    12        0        2           1
# 33        34  2011-02-03       1   0     2        0        4           1
# 300      301  2011-10-28       4   0    10        0        5           1
# 456      457  2012-04-01       2   1     4        0        0           0
# 633      634  2012-09-25       4   1     9        0        2           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 70        71  2011-03-12       1   0     3        0        6           0
# 192      193  2011-07-12       3   0     7        0        2           1
# 328      329  2011-11-25       4   0    11        0        5           1
# 165      166  2011-06-15       2   0     6        0        3           1
# 135      136  2011-05-16       2   0     5        0        1           1
#
# ...
